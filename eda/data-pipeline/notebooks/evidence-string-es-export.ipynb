# %% [markdown]
# ## Evidence Export (from Elasticsearch)
#
# This will export ES records from the evidence data index into a parquet dataset (note that these records undergo several normalizations and modifications as well as scoring by comparison to the remote GS OT urls for evidence string files).

# %%
# %run utils.py
import tqdm
import os
import os.path as osp
import json
import pandas as pd
import numpy as np
import more_itertools
from elasticsearch import helpers
import pyarrow as pa
export_dir = '/lab/data/raw/evidence-data-stage-2.parquet'

# %%
es = get_es_client()

# %%
# Show example result
es.search(index='master_evidence-data', body={"query": {"match_all": {}}})['hits']['hits'][0]
# Out:
# {'_index': 'master_evidence-data',
#  '_type': '_doc',
#  '_id': '38c0851b3dba497d71ad645a01f498c3',
#  '_score': 1.0,
#  '_source': {'access_level': 'public',
#   'disease': {'biosample': {'id': 'http://purl.obolibrary.org/obo/UBERON_0002116',
#     'name': 'ileum'},
#    'efo_info': {'efo_id': 'http://www.ebi.ac.uk/efo/EFO_0000384',
#     'label': "Crohn's disease",
#     'path': [['EFO_0000408', 'EFO_0000405', 'EFO_0003767', 'EFO_0000384'],
#      ['EFO_0000408',
#       'EFO_0000540',
#       'EFO_0005140',
#       'EFO_0003767',
#       'EFO_0000384']],
#     'therapeutic_area': {'codes': [], 'labels': []}},
#    'id': 'EFO_0000384'},
#   'evidence': {'comparison_name': "'Crohn's disease' vs 'non inflammatory bowel disease control' in 'A1b Paris classification'",
#    'confidence_level': 'medium',
#    'date_asserted': '2019-05-14T15:19:25Z',
#    'evidence_codes': ['ECO_0000295'],
#    'evidence_codes_info': [[{'eco_id': 'ECO_0000295',
#       'label': 'RNA-seq evidence'}]],
#    'experiment_overview': "RNA-seq of ileal biopsies from diagnostic endoscopy of pediatric Crohn's disease patients and non inflammatory bowel disease controls",
#    'is_associated': True,
#    'log2_fold_change': {'percentile_rank': 99, 'value': 2.1},
#    'organism_part': 'http://purl.obolibrary.org/obo/UBERON_0002116',
#    'provenance_type': {'database': {'id': 'Expression_Atlas',
#      'version': 'prod.30'}},
#    'reference_replicates_n': 37,
#    'reference_sample': 'non inflammatory bowel disease control; A1b Paris classification',
#    'resource_score': {'method': {'description': 'DESeq2 version: 1.10.1'},
#     'type': 'pvalue',
#     'value': 3.64e-06},
#    'test_replicates_n': 193,
#    'test_sample': "Crohn's disease; A1b Paris classification",
#    'unique_experiment_reference': 'STUDYID_E-GEOD-101794',
#    'urls': [{'nice_name': 'ArrayExpress Experiment overview',
#      'url': 'http://identifiers.org/arrayexpress/E-GEOD-101794'},
#     {'nice_name': 'Gene expression in Expression Atlas',
#      'url': 'http://www.ebi.ac.uk/gxa/experiments/E-GEOD-101794?geneQuery=ENSG00000134438'},
#     {'nice_name': 'Baseline gene expression in Expression Atlas',
#      'url': 'http://www.ebi.ac.uk/gxa/genes/ENSG00000134438'}]},
#   'id': '38c0851b3dba497d71ad645a01f498c3',
#   'private': {'datasource': 'expression_atlas',
#    'datatype': 'rna_expression',
#    'eco_codes': ['ECO_0000295'],
#    'efo_codes': ['EFO_0000405',
#     'EFO_0000540',
#     'EFO_0005140',
#     'EFO_0000384',
#     'EFO_0000408',
#     'EFO_0003767'],
#    'facets': {'go': {'biological_process': [{'code': 'GO:0043010',
#        'term': 'camera-type eye development'},
#       {'code': 'GO:0021854', 'term': 'hypothalamus development'},
#       {'code': 'GO:0060173', 'term': 'limb development'},
#       {'code': 'GO:0007389', 'term': 'pattern specification process'},
#       {'code': 'GO:0045944',
#        'term': 'positive regulation of transcription by RNA polymerase II'},
#       {'code': 'GO:0007601', 'term': 'visual perception'}],
#      'cellular_component': [{'code': 'GO:0000790',
#        'term': 'nuclear chromatin'}],
#      'molecular_function': [{'code': 'GO:0001228',
#        'term': 'DNA-binding transcription activator activity, RNA polymerase II-specific'},
#       {'code': 'GO:0000981',
#        'term': 'DNA-binding transcription factor activity, RNA polymerase II-specific'},
#       {'code': 'GO:0000978',
#        'term': 'RNA polymerase II proximal promoter sequence-specific DNA binding'}]},
#     'uniprot_keywords': ['Alternative splicing',
#      'Complete proteome',
#      'Developmental protein',
#      'Disease mutation',
#      'DNA-binding',
#      'Homeobox',
#      'Microphthalmia',
#      'Nucleus',
#      'Polymorphism',
#      'Reference proteome',
#      'Transcription',
#      'Transcription regulation']}},
#   'scores': {'association_score': 0.11307470223393612},
#   'sourceID': 'expression_atlas',
#   'target': {'activity': 'increased_transcript_level',
#    'gene_info': {'geneid': 'ENSG00000134438',
#     'name': 'retina and anterior neural fold homeobox',
#     'symbol': 'RAX'},
#    'id': 'ENSG00000134438',
#    'target_type': 'transcript_evidence'},
#   'type': 'rna_expression',
#   'unique_association_fields': {'comparison_name': "'Crohn's disease' vs 'non inflammatory bowel disease control' in 'A1b Paris classification'",
#    'datasource': 'expression_atlas',
#    'geneID': 'http://identifiers.org/ensembl/ENSG00000134438',
#    'study_id': 'http://identifiers.org/gxa.expt/E-GEOD-101794'}}}

# %%
# Setup scanner for entire evidence data index
batch_size = 10000
query = {"query": {"match_all": {}}}
# 1626542 records as of 20191007
res = helpers.scan(es, query, index='master_evidence-data', size=batch_size, scroll='1h')

# %%
! [ -d $export_dir ] && rm -rf $export_dir

# %%
# Use fixed schema or resulting parquet dataset will be useless otherwise
schema = pa.schema([
    pa.field("access_level", pa.string()),
    pa.field("batch", pa.int64()),
    pa.field("disease", pa.string()),
    pa.field("drug", pa.string()),
    pa.field("evidence", pa.string()),
    pa.field("id", pa.string()),
    pa.field("literature", pa.string()),
    pa.field("private", pa.string()),
    pa.field("scores", pa.string()),
    pa.field("sourceID", pa.string()),
    pa.field("target", pa.string()),
    pa.field("type", pa.string()),
    pa.field("unique_association_fields", pa.string()),
    pa.field("validated_against_schema_version", pa.string())
])

# %%
def to_value(v):
    # Convert objects to json string (leave scalars)
    return v if np.isscalar(v) else json.dumps(v)

# Loop through batches and write each as a new chunk in the parquet dataset
for i, batch in enumerate(more_itertools.chunked(tqdm.tqdm(res), batch_size)):
    df = pd.DataFrame([r['_source'] for r in batch])
    df = df.applymap(to_value)
    df['batch'] = i
    df = df[sorted(df.columns.tolist())]
    for f in schema:
        if f.name not in df:
            df[f.name] = None 
        if f.type.to_pandas_dtype() == np.object_:
            df[f.name] = df[f.name].fillna('')
        df[f.name] = df[f.name].astype(f.type.to_pandas_dtype())
    df = df[[f.name for f in schema]]
    df.to_parquet(export_dir, index=False, partition_cols=['batch'])
# Out:
# 1626543it [17:06, 1584.12it/s]

# %%
# !du -ch $export_dir
# Out:
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=103
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=104
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=132
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=135
# 12M	/lab/data/raw/evidence-data-stage-2.parquet/batch=161
# 12M	/lab/data/raw/evidence-data-stage-2.parquet/batch=159
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=150
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=157
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=134
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=133
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=105
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=102
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=156
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=151
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=158
# 12M	/lab/data/raw/evidence-data-stage-2.parquet/batch=160
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=31
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=36
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=38
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=53
# 20M	/lab/data/raw/evidence-data-stage-2.parquet/batch=98
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=54
# 20M	/lab/data/raw/evidence-data-stage-2.parquet/batch=96
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=62
# 13M	/lab/data/raw/evidence-data-stage-2.parquet/batch=65
# 8.0M	/lab/data/raw/evidence-data-stage-2.parquet/batch=91
# 10M	/lab/data/raw/evidence-data-stage-2.parquet/batch=39
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=37
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=30
# 7.9M	/lab/data/raw/evidence-data-stage-2.parquet/batch=90
# 12M	/lab/data/raw/evidence-data-stage-2.parquet/batch=64
# 12M	/lab/data/raw/evidence-data-stage-2.parquet/batch=63
# 20M	/lab/data/raw/evidence-data-stage-2.parquet/batch=97
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=55
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=52
# 20M	/lab/data/raw/evidence-data-stage-2.parquet/batch=99
# 8.0M	/lab/data/raw/evidence-data-stage-2.parquet/batch=84
# 16M	/lab/data/raw/evidence-data-stage-2.parquet/batch=70
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=48
# 9.0M	/lab/data/raw/evidence-data-stage-2.parquet/batch=77
# 8.0M	/lab/data/raw/evidence-data-stage-2.parquet/batch=83
# 10M	/lab/data/raw/evidence-data-stage-2.parquet/batch=41
# 8.0M	/lab/data/raw/evidence-data-stage-2.parquet/batch=79
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=46
# 6.4M	/lab/data/raw/evidence-data-stage-2.parquet/batch=12
# 6.3M	/lab/data/raw/evidence-data-stage-2.parquet/batch=15
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=23
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=24
# 8.1M	/lab/data/raw/evidence-data-stage-2.parquet/batch=78
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=47
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=40
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=49
# 7.9M	/lab/data/raw/evidence-data-stage-2.parquet/batch=82
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=76
# 15M	/lab/data/raw/evidence-data-stage-2.parquet/batch=71
# 8.0M	/lab/data/raw/evidence-data-stage-2.parquet/batch=85
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=25
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=22
# 6.9M	/lab/data/raw/evidence-data-stage-2.parquet/batch=14
# 6.7M	/lab/data/raw/evidence-data-stage-2.parquet/batch=13
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=142
# 7.3M	/lab/data/raw/evidence-data-stage-2.parquet/batch=5
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=145
# 7.4M	/lab/data/raw/evidence-data-stage-2.parquet/batch=2
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=120
# 20M	/lab/data/raw/evidence-data-stage-2.parquet/batch=118
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=127
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=111
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=129
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=116
# 16M	/lab/data/raw/evidence-data-stage-2.parquet/batch=144
# 7.2M	/lab/data/raw/evidence-data-stage-2.parquet/batch=3
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=143
# 7.3M	/lab/data/raw/evidence-data-stage-2.parquet/batch=4
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=128
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=117
# 20M	/lab/data/raw/evidence-data-stage-2.parquet/batch=110
# 20M	/lab/data/raw/evidence-data-stage-2.parquet/batch=119
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=126
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=121
# 6.9M	/lab/data/raw/evidence-data-stage-2.parquet/batch=162
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=154
# 9.9M	/lab/data/raw/evidence-data-stage-2.parquet/batch=153
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=107
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=138
# 20M	/lab/data/raw/evidence-data-stage-2.parquet/batch=100
# 17M	/lab/data/raw/evidence-data-stage-2.parquet/batch=136
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=109
# 17M	/lab/data/raw/evidence-data-stage-2.parquet/batch=131
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=152
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=155
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=130
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=137
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=108
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=101
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=106
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=139
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=57
# 13M	/lab/data/raw/evidence-data-stage-2.parquet/batch=68
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=50
# 13M	/lab/data/raw/evidence-data-stage-2.parquet/batch=66
# 7.9M	/lab/data/raw/evidence-data-stage-2.parquet/batch=92
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=59
# 17M	/lab/data/raw/evidence-data-stage-2.parquet/batch=95
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=61
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=35
# 9.8M	/lab/data/raw/evidence-data-stage-2.parquet/batch=32
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=60
# 13M	/lab/data/raw/evidence-data-stage-2.parquet/batch=94
# 8.5M	/lab/data/raw/evidence-data-stage-2.parquet/batch=93
# 13M	/lab/data/raw/evidence-data-stage-2.parquet/batch=67
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=58
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=51
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=56
# 14M	/lab/data/raw/evidence-data-stage-2.parquet/batch=69
# 10M	/lab/data/raw/evidence-data-stage-2.parquet/batch=33
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=34
# 7.2M	/lab/data/raw/evidence-data-stage-2.parquet/batch=16
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=29
# 7.0M	/lab/data/raw/evidence-data-stage-2.parquet/batch=11
# 9.9M	/lab/data/raw/evidence-data-stage-2.parquet/batch=27
# 6.7M	/lab/data/raw/evidence-data-stage-2.parquet/batch=18
# 9.7M	/lab/data/raw/evidence-data-stage-2.parquet/batch=20
# 12M	/lab/data/raw/evidence-data-stage-2.parquet/batch=74
# 7.9M	/lab/data/raw/evidence-data-stage-2.parquet/batch=80
# 7.7M	/lab/data/raw/evidence-data-stage-2.parquet/batch=87
# 12M	/lab/data/raw/evidence-data-stage-2.parquet/batch=73
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=45
# 8.0M	/lab/data/raw/evidence-data-stage-2.parquet/batch=89
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=42
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=21
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=26
# 6.5M	/lab/data/raw/evidence-data-stage-2.parquet/batch=19
# 7.3M	/lab/data/raw/evidence-data-stage-2.parquet/batch=10
# 7.2M	/lab/data/raw/evidence-data-stage-2.parquet/batch=17
# 9.8M	/lab/data/raw/evidence-data-stage-2.parquet/batch=28
# 8.0M	/lab/data/raw/evidence-data-stage-2.parquet/batch=88
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=43
# 11M	/lab/data/raw/evidence-data-stage-2.parquet/batch=44
# 13M	/lab/data/raw/evidence-data-stage-2.parquet/batch=72
# 7.7M	/lab/data/raw/evidence-data-stage-2.parquet/batch=86
# 8.0M	/lab/data/raw/evidence-data-stage-2.parquet/batch=81
# 13M	/lab/data/raw/evidence-data-stage-2.parquet/batch=75
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=124
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=123
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=115
# 17M	/lab/data/raw/evidence-data-stage-2.parquet/batch=112
# 7.5M	/lab/data/raw/evidence-data-stage-2.parquet/batch=146
# 7.0M	/lab/data/raw/evidence-data-stage-2.parquet/batch=1
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=141
# 7.1M	/lab/data/raw/evidence-data-stage-2.parquet/batch=6
# 7.7M	/lab/data/raw/evidence-data-stage-2.parquet/batch=148
# 7.1M	/lab/data/raw/evidence-data-stage-2.parquet/batch=8
# 17M	/lab/data/raw/evidence-data-stage-2.parquet/batch=113
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=114
# 18M	/lab/data/raw/evidence-data-stage-2.parquet/batch=122
# 19M	/lab/data/raw/evidence-data-stage-2.parquet/batch=125
# 6.1M	/lab/data/raw/evidence-data-stage-2.parquet/batch=9
# 7.8M	/lab/data/raw/evidence-data-stage-2.parquet/batch=149
# 20M	/lab/data/raw/evidence-data-stage-2.parquet/batch=140
# 7.2M	/lab/data/raw/evidence-data-stage-2.parquet/batch=7
# 7.0M	/lab/data/raw/evidence-data-stage-2.parquet/batch=147
# 6.5M	/lab/data/raw/evidence-data-stage-2.parquet/batch=0
# 2.0G	/lab/data/raw/evidence-data-stage-2.parquet
# 2.0G	total
